# %% [markdown]
# **1.Clone repository**

# %%
# !git clone https://github.com/LuongTuanAnh163002/Yolov2s.git

# %% [markdown]
# **2.Move to Yolov2s folder**

# %%
# %cd Yolov2s

# %% [markdown]
# **3.Dowload dataset**

# %%
# !bash ./script/get_fruit.sh

# %% [markdown]
# **4.Create .yaml file**

# %%
# !echo 'train: /content/Yolov2s/fruit_dataset/images/train' >> /content/Yolov2s/data/fruit.yaml
# !echo 'val: /content/Yolov2s/fruit_dataset/images/valid' >> /content/Yolov2s/data/fruit.yaml
# !echo 'voc_path_txt: None' >> /content/Yolov2s/data/fruit.yaml
# !echo 'nc: 3' >> /content/Yolov2s/data/fruit.yaml
# !echo "names: ['apple', 'banana', 'orange']" >> /content/Yolov2s/data/fruit.yaml

# %% [markdown]
# **5.Train model**

# %%
# !python train.py --data data/fruit.yaml --epochs 60 --device 0 --data_format yolo

# %% [markdown]
# **6.Detect**

# %%
# !python detect.py --source /content/Yolov2s/fruit_dataset/images/train/apple_10.jpg --weight /content/Yolov2s/runs/train/exp/weights/last.pth --device 0
